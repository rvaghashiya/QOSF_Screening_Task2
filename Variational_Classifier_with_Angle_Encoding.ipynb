# %% [markdown]
# # Install Libs and Dependencies

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.21.0-py3-none-any.whl (800 kB)
#      |████████████████████████████████| 800 kB 23.1 MB/s
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from pennylane) (2.6.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/dist-packages (from pennylane) (4.2.4)
# Collecting semantic-version==2.6
#   Downloading semantic_version-2.6.0-py3-none-any.whl (14 kB)
# Collecting retworkx
#   Downloading retworkx-0.11.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 48.6 MB/s
# Collecting pennylane-lightning>=0.21
#   Downloading PennyLane_Lightning-0.21.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 53.9 MB/s
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from pennylane) (1.4.4)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pennylane) (1.21.5)
# Collecting autoray
#   Downloading autoray-0.2.5-py3-none-any.whl (16 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.7/dist-packages (from pennylane) (1.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pennylane) (1.4.1)
# Collecting ninja
#   Downloading ninja-1.10.2.3-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (108 kB)
#      |████████████████████████████████| 108 kB 46.6 MB/s
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd->pennylane) (0.16.0)
# Installing collected packages: ninja, toml, semantic-version, retworkx, pennylane-lightning, autoray, pennylane
# Successfully installed autoray-0.2.5 ninja-1.10.2.3 pennylane-0.21.0 pennylane-lightning-0.21.0 retworkx-0.11.0 semantic-version-2.6.0 toml-0.10.2

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import AdamOptimizer
from pennylane.templates.embeddings import AngleEmbedding

from pathlib import Path
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Load Data

# %%
# Load train and test dataset
train_df_loc = Path( "mock_train_set.csv" )
test_df_loc  = Path( "mock_test_set.csv" )

train_df = pd.read_csv(train_df_loc)
test_df  = pd.read_csv(test_df_loc)

train_df = train_df.astype({"1":int, "2": int, "3": int, "4": int})
test_df  = test_df.astype( {"1":int, "2": int, "3": int, "4": int})
train_df
# Out:
#            0        1       2   3  4
# 0    2789.26     1000      10  20  0
# 1    4040.01  1000000       1   1  1
# 2    2931.20    10000   10000  40  1
# 3    3896.54    10000  100000  30  1
# 4     982.06      100    1000  75  0
# ..       ...      ...     ...  .. ..
# 295  1464.52  1000000   10000  45  1
# 296  3493.66  1000000  100000  85  1
# 297  4182.81        1       1  65  0
# 298  3113.75    10000     100   1  1
# 299  4567.57    10000  100000  90  1
#
# [300 rows x 5 columns]

# %% [markdown]
# # EDA

# %%
# Dataset statistics
train_df.describe()
# Out:
#                  0               1               2           3           4
# count   300.000000      300.000000      300.000000  300.000000  300.000000
# mean   2630.877933   308630.410000   127187.050000   46.220000    0.476667
# std    1416.096576   460586.067687   314218.134392   27.488488    0.500290
# min      42.350000        1.000000        1.000000    1.000000    0.000000
# 25%    1408.067500        1.000000       10.000000   20.000000    0.000000
# 50%    2672.180000     1000.000000     1000.000000   50.000000    0.000000
# 75%    3895.692500  1000000.000000    10000.000000   70.000000    1.000000
# max    4995.610000  1000000.000000  1000000.000000   90.000000    1.000000

# %%
# Feature Correlation Analysis
plt.figure(figsize=(8,6))
plt.title('Pearson Correlation of Features', size = 15)
colormap = sns.diverging_palette(10, 220, as_cmap = True)
sns.heatmap(train_df.corr(),
            cmap = colormap,
            square = True,
            annot = True,
            linewidths=0.1,vmax=1.0, linecolor='white',
            annot_kws={'fontsize':12 })
plt.show()

# %%
# Analyze data range of column_3
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})
sns.distplot(
    train_df['3'], norm_hist=False, kde=True, bins=20, hist_kws={"alpha": 1}
).set(xlabel='3', ylabel='Count');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Visualize pairwise relationships in a dataset.
sns.pairplot(train_df)

# %% [markdown]
# # Feature Preprocessing

# %%
# As values in Column_1 and Column_2 are discrete and in multiples of 10,
# log(base 10) transform is performed on Column_1 and Column_2 of train and test dataset
for i in range(1,3):
    train_df[str(i)] = np.log10(train_df[str(i)])
    test_df[str(i)]  = np.log10(test_df[str(i)])

# %%
# Normalize columns in train and test datasets to fit in the range (-np.pi, np.pi) 
# for subsequent angle encoding
scaler = MinMaxScaler(feature_range=(-np.pi, np.pi))

for i in range(4):
    train_df[[str(i)]] = scaler.fit_transform( train_df[[str(i)]] )
    test_df[[str(i)]]  = scaler.transform( test_df[[str(i)]] )

# %%
# Split train dataframe into the respective feature set and ground truth labels
X_training = train_df.iloc[:, :-1]    # select only the features by dropping the last column
Y_training = train_df.iloc[:, -1]     # select only the labels by selecting the last column

# Split test dataframe into the respective feature set and ground truth labels
X_test = test_df.iloc[:, :-1]    # select only the features by dropping the last column
Y_test = test_df.iloc[:, -1]     # select only the labels by selecting the last column

# Freeze the input training and test data
X_training = np.array(X_training, dtype=np.float32, requires_grad= False)
Y_training = np.array(Y_training, dtype=np.int32, requires_grad= False)

X_test  = np.array(X_test, dtype=np.float32, requires_grad= False)
Y_test  = np.array(Y_test, dtype=np.int32, requires_grad= False)

# Shift ground truth labels from {0, 1} to {-1, 1}
# to match PauliZ expectation values
Y_training = Y_training * 2 - np.ones(len(Y_training))
Y_test = Y_test * 2 - np.ones(len(Y_test))

# %%
# Seed for reproducibility
np.random.seed(0)

# Split training data into train and validation sets
num_data = len(Y_training)
num_train = int(0.75 * num_data)

# Shuffle the training data and split into train and validation sets
index = np.random.permutation(range(num_data))

X_train = X_training[index[:num_train]]
Y_train = Y_training[index[:num_train]]

X_val = X_training[index[num_train:]]
Y_val = Y_training[index[num_train:]]

# %% [markdown]
# # Circuit Generation

# %% [markdown]
# In angle encoding, $N$ classical features are encoded into the rotation angles of $n$ qubits, where $N ≤ n$.

# %%
# Here, we use 4 qubits, one for each classical feature
num_qubits = 4

dev = qml.device('default.qubit', wires=num_qubits) #shots=1000

# %%
# Define a Layer Template as a sequence of trainable gates.
# It is similar to the layers in a neural network.
def layer(W):
    # Single qubit rotations
    for i in range(num_qubits):
        qml.Rot(W[i,0], W[i,1], W[i,2], wires=i)
    
    # Entanglers between pairs of qubits
    for j in range(num_qubits-1):
        qml.CNOT(wires=[j, j+1])

    if num_qubits >= 2:
        qml.CNOT(wires=[num_qubits-1, 0])

# %%
# Initialize a quantum device
@qml.qnode(dev)
def circuit(weights, x):
    
    #Prepare Quantum Dataset
    for i in range(2):
        qml.Hadamard(i)

    # Embed classical data as a quantum state in the Hilbert space
    AngleEmbedding(features=x, wires=range(4),rotation='Y')
    
    # Quantum Model
    for W in weights:
        layer(W)
    
    return qml.expval(qml.PauliZ(0))

# %%
# Define squared loss as the loss function
def square_loss(labels, preds):
    loss = 0 
    for l,p in zip(labels, preds):
        loss += (l-p)**2
    loss = 2*loss / len(labels)
    return loss

# Define model accuracy for binary classification
def accuracy(labels, preds):
    correct_samples = 0
    for l,p in zip(labels, preds):
        if abs(l-p) < 1e-5:
            correct_samples += 1

    correct_samples /= len(labels)
    return correct_samples

# %%
# Define Variational Quantum Classifier
def variational_classifier(weights, bias, x):
    return circuit(weights, x) + bias

# Define Cost function for the classifier
def cost(weights, bias, inputs, labels):    
    preds = [variational_classifier(weights, bias, x) for x in inputs]
    return square_loss(labels, preds)

# %%
# Train the Qunatum classifier
def train_classifier(X_train, Y_train, batch_size=50, total_iterations=100,
                     learning_rate=0.01, weights=None, bias=None, num_train=None):

    opt = AdamOptimizer(stepsize = learning_rate)
    
    costs, train_accs, val_accs = [], [], []

    for iter in range(total_iterations):

        # Shuffle train data
        indices = np.arange(X_train.shape[0])
        np.random.shuffle(indices)
        excerpt = indices[:batch_size]

        # Extract slice of the shuffled data
        X_batch = X_train[excerpt]
        Y_batch = Y_train[excerpt]

        # Update trainable arguments with one step of the optimizer
        weights, bias, _, _ = opt.step(cost, weights, bias, X_batch, Y_batch)

        # Evaluate classifier output for train and validation set
        preds_train = [np.sign(variational_classifier(weights, bias, x)) for x in X_train ]
        preds_val =   [np.sign(variational_classifier(weights, bias, x)) for x in X_val ]
        
        # Calculate accuracy for train and validation set
        acc_train = accuracy(Y_train, preds_train)
        acc_val = accuracy(Y_val, preds_val)

        # Store model loss, training accuracy, and validation accuracy
        costs.append(cost(weights, bias, X_train, Y_train))
        train_accs.append(acc_train)
        val_accs.append(acc_val)

        print(
            "Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
            "".format(iter + 1, costs[-1], train_accs[-1], val_accs[-1])
        )

    # Evaluate model performance on test data
    preds_test = [np.sign(variational_classifier(weights, bias, x)) for x in X_test]
    acc_test = accuracy(Y_test, preds_test)
    
    print(
            "Acc test: {:0.7f} "
            "".format(acc_test)
        )

    # Plot model training performance
    fig, ax1 = plt.subplots()
    iters = np.arange(0, total_iterations, 1)
    colors = ["tab:red", "tab:blue"]
    ax1.set_xlabel("Iterations", fontsize=17)
    ax1.set_ylabel("Cost", fontsize=17, color=colors[0])
    ax1.plot(iters, costs, color=colors[0], linewidth=2)
    ax1.tick_params(axis="y", labelsize=14, labelcolor=colors[0])

    ax2 = ax1.twinx()
    ax2.set_ylabel("Test Acc.", fontsize=17, color=colors[1])
    ax2.plot(iters, val_accs, color=colors[1], linewidth=2)

    ax2.tick_params(axis="x", labelsize=14)
    ax2.tick_params(axis="y", labelsize=14, labelcolor=colors[1])

    plt.grid(False)
    plt.tight_layout()
    plt.show()
        
    # Plot confusion matrix
    conf_mat = confusion_matrix(y_true = Y_test, y_pred = preds_test, labels=[-1,1])
    
    labels = ["{0:0.0f}".format(value) for value in conf_mat.flatten()]
    labels = np.asarray(labels).reshape(2,2)
    df_cm = pd.DataFrame(conf_mat, index=[0,1], columns=[0,1])
    plt.figure(figsize=(5,3))
    sns.set(font_scale=1.4) # for label size
    sns.heatmap(df_cm, annot_kws={"size": 16}, annot=labels, fmt="", square=True, linewidths=0.5, cmap='rocket_r')
    plt.yticks( verticalalignment='center')
    plt.title('Confusion Matrix')
    plt.show()

# %%
# Initialize the weights and bias of the model layers
num_layers = 1
weights_init = 0.01 * np.random.randn(num_layers, num_qubits, 3, requires_grad=True)
bias_init = np.array(0.0, requires_grad=True)

print(weights_init, bias_init)

# train the classifier
train_classifier(X_train, Y_train, batch_size=150, total_iterations=100, learning_rate=0.1, weights=weights_init, bias=bias_init, num_train = num_train)
# Out:
# [[[ 0.00583077  0.01039786 -0.01010511]
#   [-0.00208975  0.00897529  0.00181226]
#   [ 0.00826782 -0.00163268  0.0238201 ]
#   [ 0.0006954   0.0023726   0.01223039]]] 0.0
# Iter:     1 | Cost: 2.0780214 | Acc train: 0.5777778 | Acc validation: 0.5733333
# Iter:     2 | Cost: 2.0528720 | Acc train: 0.5600000 | Acc validation: 0.5333333
# Iter:     3 | Cost: 2.0523427 | Acc train: 0.5288889 | Acc validation: 0.4800000
# Iter:     4 | Cost: 2.0589989 | Acc train: 0.5111111 | Acc validation: 0.4800000
# Iter:     5 | Cost: 2.0549980 | Acc train: 0.5022222 | Acc validation: 0.5333333
# Iter:     6 | Cost: 2.0481593 | Acc train: 0.5288889 | Acc validation: 0.5333333
# Iter:     7 | Cost: 2.0375441 | Acc train: 0.5422222 | Acc validation: 0.5466667
# Iter:     8 | Cost: 2.0241814 | Acc train: 0.5466667 | Acc validation: 0.5466667
# Iter:     9 | Cost: 2.0132798 | Acc train: 0.5466667 | Acc validation: 0.5466667
# Iter:    10 | Cost: 2.0029235 | Acc train: 0.5600000 | Acc validation: 0.5600000
# Iter:    11 | Cost: 1.9929161 | Acc train: 0.5600000 | Acc validation: 0.5600000
# Iter:    12 | Cost: 1.9841945 | Acc train: 0.5688889 | Acc validation: 0.5733333
# Iter:    13 | Cost: 1.9771204 | Acc train: 0.5555556 | Acc validation: 0.5733333
# Iter:    14 | Cost: 1.9722864 | Acc train: 0.5600000 | Acc validation: 0.5733333
# Iter:    15 | Cost: 1.9678029 | Acc train: 0.5466667 | Acc validation: 0.5466667
# Iter:    16 | Cost: 1.9649548 | Acc train: 0.5555556 | Acc validation: 0.5600000
# Iter:    17 | Cost: 1.9608116 | Acc train: 0.5555556 | Acc validation: 0.5600000
# Iter:    18 | Cost: 1.9579511 | Acc train: 0.6000000 | Acc validation: 0.5733333
# Iter:    19 | Cost: 1.9579884 | Acc train: 0.5955556 | Acc validation: 0.5866667
# Iter:    20 | Cost: 1.9623910 | Acc train: 0.5777778 | Acc validation: 0.5733333
# Iter:    21 | Cost: 1.9676492 | Acc train: 0.5733333 | Acc validation: 0.5733333
# Iter:    86 | Cost: 1.9252575 | Acc train: 0.6355556 | Acc validation: 0.5866667
# Iter:    87 | Cost: 1.9294786 | Acc train: 0.6222222 | Acc validation: 0.5600000
# Iter:    88 | Cost: 1.9349189 | Acc train: 0.6311111 | Acc validation: 0.5600000
# Iter:    89 | Cost: 1.9418926 | Acc train: 0.6266667 | Acc validation: 0.5600000
# Iter:    90 | Cost: 1.9491500 | Acc train: 0.6222222 | Acc validation: 0.5466667
# Iter:    91 | Cost: 1.9502620 | Acc train: 0.6222222 | Acc validation: 0.5466667
# Iter:    92 | Cost: 1.9501372 | Acc train: 0.6222222 | Acc validation: 0.5466667
# Iter:    93 | Cost: 1.9477184 | Acc train: 0.6222222 | Acc validation: 0.5466667
# Iter:    94 | Cost: 1.9423161 | Acc train: 0.6088889 | Acc validation: 0.5733333
# Iter:    95 | Cost: 1.9381754 | Acc train: 0.6000000 | Acc validation: 0.5733333
# Iter:    96 | Cost: 1.9330456 | Acc train: 0.5733333 | Acc validation: 0.5733333
# Iter:    97 | Cost: 1.9292322 | Acc train: 0.5822222 | Acc validation: 0.5733333
# Iter:    98 | Cost: 1.9262002 | Acc train: 0.6222222 | Acc validation: 0.5733333
# Iter:    99 | Cost: 1.9257596 | Acc train: 0.6222222 | Acc validation: 0.5733333
# Iter:   100 | Cost: 1.9266441 | Acc train: 0.6222222 | Acc validation: 0.5866667
# Acc test: 0.5583333

# %%
# Initialize the weights and bias of the model layers
num_layers = 1
weights_init = 0.01 * np.random.randn(num_layers, num_qubits, 3, requires_grad=True)
bias_init = np.array(0.0, requires_grad=True)

# train the classifier
train_classifier(X_train, Y_train, batch_size=150, total_iterations=100, learning_rate=0.01, weights=weights_init, bias=bias_init, num_train = num_train)
# Out:
# [[[ 0.00285873 -0.00858536 -0.00766046]
#   [ 0.00345916 -0.01967242  0.00301911]
#   [-0.00740175 -0.01026039  0.01280443]
#   [ 0.00055894  0.00468078 -0.00648092]]] 0.0
# Iter:     1 | Cost: 2.0889053 | Acc train: 0.5688889 | Acc validation: 0.5733333
# Iter:     2 | Cost: 2.0863702 | Acc train: 0.5644444 | Acc validation: 0.5866667
# Iter:     3 | Cost: 2.0836551 | Acc train: 0.5688889 | Acc validation: 0.5733333
# Iter:     4 | Cost: 2.0811117 | Acc train: 0.5688889 | Acc validation: 0.5733333
# Iter:     5 | Cost: 2.0790277 | Acc train: 0.5688889 | Acc validation: 0.5733333
# Iter:     6 | Cost: 2.0769342 | Acc train: 0.5688889 | Acc validation: 0.5733333
# Iter:     7 | Cost: 2.0749921 | Acc train: 0.5822222 | Acc validation: 0.5600000
# Iter:     8 | Cost: 2.0732079 | Acc train: 0.5733333 | Acc validation: 0.5600000
# Iter:     9 | Cost: 2.0714885 | Acc train: 0.5777778 | Acc validation: 0.5466667
# Iter:    10 | Cost: 2.0699698 | Acc train: 0.5822222 | Acc validation: 0.5333333
# Iter:    11 | Cost: 2.0686029 | Acc train: 0.5777778 | Acc validation: 0.5333333
# Iter:    83 | Cost: 2.0366573 | Acc train: 0.5511111 | Acc validation: 0.5200000
# Iter:    84 | Cost: 2.0361352 | Acc train: 0.5466667 | Acc validation: 0.5200000
# Iter:    85 | Cost: 2.0355851 | Acc train: 0.5466667 | Acc validation: 0.5200000
# Iter:    86 | Cost: 2.0348531 | Acc train: 0.5511111 | Acc validation: 0.5200000
# Iter:    87 | Cost: 2.0341686 | Acc train: 0.5422222 | Acc validation: 0.5200000
# Iter:    88 | Cost: 2.0333419 | Acc train: 0.5422222 | Acc validation: 0.5333333
# Iter:    89 | Cost: 2.0325162 | Acc train: 0.5422222 | Acc validation: 0.5333333
# Iter:    90 | Cost: 2.0316125 | Acc train: 0.5422222 | Acc validation: 0.5333333
# Iter:    91 | Cost: 2.0308071 | Acc train: 0.5422222 | Acc validation: 0.5333333
# Iter:    92 | Cost: 2.0299173 | Acc train: 0.5422222 | Acc validation: 0.5333333
# Iter:    93 | Cost: 2.0290484 | Acc train: 0.5422222 | Acc validation: 0.5333333
# Iter:    94 | Cost: 2.0282284 | Acc train: 0.5333333 | Acc validation: 0.5333333
# Iter:    95 | Cost: 2.0272684 | Acc train: 0.5333333 | Acc validation: 0.5333333
# Iter:    96 | Cost: 2.0263121 | Acc train: 0.5333333 | Acc validation: 0.5333333
# Iter:    97 | Cost: 2.0252893 | Acc train: 0.5333333 | Acc validation: 0.5333333
# Iter:    98 | Cost: 2.0243386 | Acc train: 0.5333333 | Acc validation: 0.5333333
# Iter:    99 | Cost: 2.0233412 | Acc train: 0.5333333 | Acc validation: 0.5333333
# Iter:   100 | Cost: 2.0223436 | Acc train: 0.5333333 | Acc validation: 0.5333333
# Acc test: 0.5916667

# %%
# Initialize the weights and bias of the model layers
num_layers = 2
weights_init = 0.01 * np.random.randn(num_layers, num_qubits, 3, requires_grad=True)
bias_init = np.array(0.0, requires_grad=True)

# train the classifier
train_classifier(X_train, Y_train, batch_size=150, total_iterations=100, learning_rate=0.01, weights=weights_init, bias=bias_init, num_train = num_train)
# Out:
# Iter:     1 | Cost: 2.1534610 | Acc train: 0.4488889 | Acc validation: 0.4133333
# Iter:     2 | Cost: 2.1520509 | Acc train: 0.4311111 | Acc validation: 0.4266667
# Iter:     3 | Cost: 2.1506136 | Acc train: 0.4311111 | Acc validation: 0.4400000
# Iter:     4 | Cost: 2.1485556 | Acc train: 0.4444444 | Acc validation: 0.3733333
# Iter:     5 | Cost: 2.1461352 | Acc train: 0.4444444 | Acc validation: 0.3600000
# Iter:     6 | Cost: 2.1436306 | Acc train: 0.4666667 | Acc validation: 0.4000000
# Iter:     7 | Cost: 2.1413870 | Acc train: 0.4711111 | Acc validation: 0.4133333
# Iter:     8 | Cost: 2.1389680 | Acc train: 0.4711111 | Acc validation: 0.4266667
# Iter:     9 | Cost: 2.1366795 | Acc train: 0.4844444 | Acc validation: 0.4533333
# Iter:    10 | Cost: 2.1345458 | Acc train: 0.4977778 | Acc validation: 0.4666667
# Iter:    76 | Cost: 1.9265543 | Acc train: 0.5866667 | Acc validation: 0.4666667
# Iter:    77 | Cost: 1.9242847 | Acc train: 0.5911111 | Acc validation: 0.4800000
# Iter:    78 | Cost: 1.9219998 | Acc train: 0.5911111 | Acc validation: 0.4933333
# Iter:    79 | Cost: 1.9199094 | Acc train: 0.6000000 | Acc validation: 0.4933333
# Iter:    80 | Cost: 1.9178139 | Acc train: 0.6044444 | Acc validation: 0.4933333
# Iter:    81 | Cost: 1.9157664 | Acc train: 0.6044444 | Acc validation: 0.4933333
# Iter:    82 | Cost: 1.9137603 | Acc train: 0.6044444 | Acc validation: 0.4933333
# Iter:    83 | Cost: 1.9118000 | Acc train: 0.6000000 | Acc validation: 0.4933333
# Iter:    84 | Cost: 1.9098851 | Acc train: 0.6000000 | Acc validation: 0.4666667
# Iter:    85 | Cost: 1.9078388 | Acc train: 0.6000000 | Acc validation: 0.4800000
# Iter:    86 | Cost: 1.9058521 | Acc train: 0.5955556 | Acc validation: 0.4800000
# Iter:    87 | Cost: 1.9039968 | Acc train: 0.6044444 | Acc validation: 0.4800000
# Iter:    88 | Cost: 1.9021539 | Acc train: 0.6000000 | Acc validation: 0.4800000
# Iter:    89 | Cost: 1.9002817 | Acc train: 0.5955556 | Acc validation: 0.4800000
# Iter:    90 | Cost: 1.8984592 | Acc train: 0.6000000 | Acc validation: 0.4800000
# Iter:    91 | Cost: 1.8966956 | Acc train: 0.5911111 | Acc validation: 0.4666667
# Iter:    92 | Cost: 1.8949691 | Acc train: 0.5911111 | Acc validation: 0.4666667
# Iter:    93 | Cost: 1.8933281 | Acc train: 0.5955556 | Acc validation: 0.4800000
# Iter:    94 | Cost: 1.8916567 | Acc train: 0.6000000 | Acc validation: 0.4800000
# Iter:    95 | Cost: 1.8900367 | Acc train: 0.6000000 | Acc validation: 0.4800000
# Iter:    96 | Cost: 1.8884824 | Acc train: 0.6088889 | Acc validation: 0.4800000
# Iter:    97 | Cost: 1.8869751 | Acc train: 0.6177778 | Acc validation: 0.4800000
# Iter:    98 | Cost: 1.8854412 | Acc train: 0.6222222 | Acc validation: 0.4666667
# Iter:    99 | Cost: 1.8840126 | Acc train: 0.6222222 | Acc validation: 0.4666667
# Iter:   100 | Cost: 1.8825517 | Acc train: 0.6222222 | Acc validation: 0.4666667
# Acc test: 0.5583333

# %%
# Initialize the weights and bias of the model layers
num_layers = 3
weights_init = 0.01 * np.random.randn(num_layers, num_qubits, 3, requires_grad=True)
bias_init = np.array(0.0, requires_grad=True)

# train the classifier
train_classifier(X_train, Y_train, batch_size=150, total_iterations=100, learning_rate=0.01, weights=weights_init, bias=bias_init, num_train = num_train)
# Out:
# Iter:     1 | Cost: 3.2798972 | Acc train: 0.3822222 | Acc validation: 0.3866667
# Iter:     2 | Cost: 3.2659854 | Acc train: 0.3822222 | Acc validation: 0.3733333
# Iter:     3 | Cost: 3.2515476 | Acc train: 0.4000000 | Acc validation: 0.3333333
# Iter:     4 | Cost: 3.2367604 | Acc train: 0.4088889 | Acc validation: 0.3200000
# Iter:     5 | Cost: 3.2215931 | Acc train: 0.4044444 | Acc validation: 0.3066667
# Iter:     6 | Cost: 3.2058165 | Acc train: 0.4088889 | Acc validation: 0.3066667
# Iter:     7 | Cost: 3.1896514 | Acc train: 0.4133333 | Acc validation: 0.3066667
# Iter:     8 | Cost: 3.1721744 | Acc train: 0.4133333 | Acc validation: 0.3066667
# Iter:     9 | Cost: 3.1534990 | Acc train: 0.4133333 | Acc validation: 0.3066667
# Iter:    10 | Cost: 3.1340620 | Acc train: 0.4133333 | Acc validation: 0.3333333
# Iter:    11 | Cost: 3.1133012 | Acc train: 0.4133333 | Acc validation: 0.3333333
# Iter:    12 | Cost: 3.0914124 | Acc train: 0.4133333 | Acc validation: 0.3333333
# Iter:    13 | Cost: 3.0682893 | Acc train: 0.4222222 | Acc validation: 0.3333333
# Iter:    14 | Cost: 3.0444180 | Acc train: 0.4266667 | Acc validation: 0.3466667
# Iter:    15 | Cost: 3.0193872 | Acc train: 0.4266667 | Acc validation: 0.3466667
# Iter:    16 | Cost: 2.9936392 | Acc train: 0.4311111 | Acc validation: 0.3466667
# Iter:    17 | Cost: 2.9670054 | Acc train: 0.4266667 | Acc validation: 0.3466667
# Iter:    18 | Cost: 2.9397384 | Acc train: 0.4311111 | Acc validation: 0.3466667
# Iter:    19 | Cost: 2.9115181 | Acc train: 0.4311111 | Acc validation: 0.3600000
# Iter:    20 | Cost: 2.8824857 | Acc train: 0.4355556 | Acc validation: 0.3600000
# Iter:    21 | Cost: 2.8529941 | Acc train: 0.4311111 | Acc validation: 0.3600000
# Iter:    22 | Cost: 2.8231416 | Acc train: 0.4311111 | Acc validation: 0.3600000
# Iter:    23 | Cost: 2.7927470 | Acc train: 0.4311111 | Acc validation: 0.3600000
# Iter:    24 | Cost: 2.7618608 | Acc train: 0.4266667 | Acc validation: 0.3600000
# Iter:    25 | Cost: 2.7307630 | Acc train: 0.4177778 | Acc validation: 0.3600000
# Iter:    26 | Cost: 2.6992833 | Acc train: 0.4266667 | Acc validation: 0.3466667
# Iter:    27 | Cost: 2.6678509 | Acc train: 0.4222222 | Acc validation: 0.3466667
# Iter:    28 | Cost: 2.6365131 | Acc train: 0.4222222 | Acc validation: 0.3733333
# Iter:    29 | Cost: 2.6049756 | Acc train: 0.4222222 | Acc validation: 0.3733333
# Iter:    30 | Cost: 2.5736488 | Acc train: 0.4266667 | Acc validation: 0.3600000
# Iter:    31 | Cost: 2.5425621 | Acc train: 0.4311111 | Acc validation: 0.3466667
# Iter:    32 | Cost: 2.5117991 | Acc train: 0.4311111 | Acc validation: 0.3466667
# Iter:    33 | Cost: 2.4809690 | Acc train: 0.4400000 | Acc validation: 0.3466667
# Iter:    34 | Cost: 2.4502691 | Acc train: 0.4400000 | Acc validation: 0.3466667
# Iter:    35 | Cost: 2.4197002 | Acc train: 0.4577778 | Acc validation: 0.3466667
# Iter:    36 | Cost: 2.3895880 | Acc train: 0.4755556 | Acc validation: 0.3466667
# Iter:    37 | Cost: 2.3596916 | Acc train: 0.4755556 | Acc validation: 0.3600000
# Iter:    38 | Cost: 2.3306283 | Acc train: 0.4888889 | Acc validation: 0.3733333
# Iter:    39 | Cost: 2.3021418 | Acc train: 0.4933333 | Acc validation: 0.3600000
# Iter:    40 | Cost: 2.2742493 | Acc train: 0.5111111 | Acc validation: 0.3600000
# Iter:    41 | Cost: 2.2465093 | Acc train: 0.5244444 | Acc validation: 0.3600000
# Iter:    42 | Cost: 2.2193850 | Acc train: 0.5333333 | Acc validation: 0.3733333
# Iter:    43 | Cost: 2.1928242 | Acc train: 0.5288889 | Acc validation: 0.3866667
# Iter:    44 | Cost: 2.1671313 | Acc train: 0.5422222 | Acc validation: 0.3866667
# Iter:    45 | Cost: 2.1418130 | Acc train: 0.5555556 | Acc validation: 0.4000000
# Iter:    46 | Cost: 2.1170504 | Acc train: 0.5644444 | Acc validation: 0.4133333
# Iter:    47 | Cost: 2.0929195 | Acc train: 0.5555556 | Acc validation: 0.4266667
# Iter:    48 | Cost: 2.0699359 | Acc train: 0.5555556 | Acc validation: 0.4266667
# Iter:    49 | Cost: 2.0476518 | Acc train: 0.5511111 | Acc validation: 0.4266667
# Iter:    50 | Cost: 2.0259531 | Acc train: 0.5511111 | Acc validation: 0.4266667
# Iter:    51 | Cost: 2.0049442 | Acc train: 0.5511111 | Acc validation: 0.4400000
# Iter:    52 | Cost: 1.9844430 | Acc train: 0.5644444 | Acc validation: 0.4533333
# Iter:    53 | Cost: 1.9647042 | Acc train: 0.5688889 | Acc validation: 0.4666667
# Iter:    54 | Cost: 1.9456236 | Acc train: 0.5733333 | Acc validation: 0.4666667
# Iter:    55 | Cost: 1.9275504 | Acc train: 0.5733333 | Acc validation: 0.4533333
# Iter:    56 | Cost: 1.9102194 | Acc train: 0.5911111 | Acc validation: 0.4533333
# Iter:    57 | Cost: 1.8938179 | Acc train: 0.6088889 | Acc validation: 0.4533333
# Iter:    58 | Cost: 1.8783144 | Acc train: 0.6266667 | Acc validation: 0.4800000
# Iter:    59 | Cost: 1.8634088 | Acc train: 0.6266667 | Acc validation: 0.4933333
# Iter:    60 | Cost: 1.8491276 | Acc train: 0.6400000 | Acc validation: 0.5066667
# Iter:    61 | Cost: 1.8354971 | Acc train: 0.6444444 | Acc validation: 0.5333333
# Iter:    62 | Cost: 1.8226499 | Acc train: 0.6444444 | Acc validation: 0.5333333
# Iter:    63 | Cost: 1.8103422 | Acc train: 0.6488889 | Acc validation: 0.5333333
# Iter:    64 | Cost: 1.7986992 | Acc train: 0.6444444 | Acc validation: 0.5333333
# Iter:    65 | Cost: 1.7877087 | Acc train: 0.6488889 | Acc validation: 0.5466667
# Iter:    66 | Cost: 1.7771462 | Acc train: 0.6488889 | Acc validation: 0.5466667
# Iter:    67 | Cost: 1.7668716 | Acc train: 0.6577778 | Acc validation: 0.5466667
# Iter:    68 | Cost: 1.7568436 | Acc train: 0.6622222 | Acc validation: 0.5466667
# Iter:    69 | Cost: 1.7470768 | Acc train: 0.6711111 | Acc validation: 0.5466667
# Iter:    70 | Cost: 1.7373929 | Acc train: 0.6755556 | Acc validation: 0.5466667
# Iter:    71 | Cost: 1.7277637 | Acc train: 0.6800000 | Acc validation: 0.5466667
# Iter:    72 | Cost: 1.7182387 | Acc train: 0.6800000 | Acc validation: 0.5466667
# Iter:    73 | Cost: 1.7088932 | Acc train: 0.6800000 | Acc validation: 0.5466667
# Iter:    74 | Cost: 1.6996931 | Acc train: 0.6800000 | Acc validation: 0.5600000
# Iter:    75 | Cost: 1.6905913 | Acc train: 0.6800000 | Acc validation: 0.5600000
# Iter:    76 | Cost: 1.6815422 | Acc train: 0.6888889 | Acc validation: 0.5733333
# Iter:    77 | Cost: 1.6724034 | Acc train: 0.6977778 | Acc validation: 0.5600000
# Iter:    78 | Cost: 1.6632573 | Acc train: 0.7022222 | Acc validation: 0.5600000
# Iter:    79 | Cost: 1.6541133 | Acc train: 0.7066667 | Acc validation: 0.5600000
# Iter:    80 | Cost: 1.6449757 | Acc train: 0.7066667 | Acc validation: 0.5466667
# Iter:    81 | Cost: 1.6359962 | Acc train: 0.7066667 | Acc validation: 0.5733333
# Iter:    82 | Cost: 1.6269875 | Acc train: 0.7111111 | Acc validation: 0.5733333
# Iter:    83 | Cost: 1.6178366 | Acc train: 0.7111111 | Acc validation: 0.5733333
# Iter:    84 | Cost: 1.6085523 | Acc train: 0.7111111 | Acc validation: 0.5866667
# Iter:    85 | Cost: 1.5993234 | Acc train: 0.7066667 | Acc validation: 0.5866667
# Iter:    86 | Cost: 1.5900031 | Acc train: 0.7155556 | Acc validation: 0.5866667
# Iter:    87 | Cost: 1.5807517 | Acc train: 0.7155556 | Acc validation: 0.5866667
# Iter:    88 | Cost: 1.5714956 | Acc train: 0.7200000 | Acc validation: 0.5866667
# Iter:    89 | Cost: 1.5622934 | Acc train: 0.7200000 | Acc validation: 0.6000000
# Iter:    90 | Cost: 1.5529331 | Acc train: 0.7111111 | Acc validation: 0.6000000
# Iter:    91 | Cost: 1.5431582 | Acc train: 0.7155556 | Acc validation: 0.5866667
# Iter:    92 | Cost: 1.5330757 | Acc train: 0.7200000 | Acc validation: 0.6000000
# Iter:    93 | Cost: 1.5229527 | Acc train: 0.7200000 | Acc validation: 0.6000000
# Iter:    94 | Cost: 1.5126369 | Acc train: 0.7200000 | Acc validation: 0.5733333
# Iter:    95 | Cost: 1.5023504 | Acc train: 0.7288889 | Acc validation: 0.5733333
# Iter:    96 | Cost: 1.4920651 | Acc train: 0.7288889 | Acc validation: 0.5866667
# Iter:    97 | Cost: 1.4817178 | Acc train: 0.7377778 | Acc validation: 0.5866667
# Iter:    98 | Cost: 1.4715414 | Acc train: 0.7377778 | Acc validation: 0.5866667
# Iter:    99 | Cost: 1.4613107 | Acc train: 0.7422222 | Acc validation: 0.6000000
# Iter:   100 | Cost: 1.4509973 | Acc train: 0.7466667 | Acc validation: 0.6000000
# Acc test: 0.7666667
